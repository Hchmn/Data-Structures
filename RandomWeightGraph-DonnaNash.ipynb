# %%
import numpy as np
import random
class Vertex:
    def __init__ (self,value):
        self.value = value
        self.degrees = 0
        self.neighbors = {}
        self.traverse = False
        
    def set_traverse(self,traverse):
        self.traverse = traverse
        
    def get_traverse(self):
        return self.traverse
        
    def set_degrees(self,degrees):
        self.degrees = len(neighbors)
    
    def set_neighbors(self,vertex,weight):
        if self != vertex and vertex not in self.neighbors:
            self.neighbors[vertex] = weight
        
    def get_degrees(self):
        return self.degrees
    
    def get_neighbors(self):
        return self.neighbors
    
    def get_value(self):
        return self.value
    
class Graph:
    
    def __init__(self):
        self.vertex = list(np.arange(1,100))
        self.vertex_length = len(self.vertex)
        self.vertices =  []
        self.value = 0
        
    
    def get_vertices(self):
        return self.vertices
    
    def set_vertices(self,vertex):
        self.vertices.append(vertex)
        
    def generate_vertex(self):
    
        for ii in range(0,20):
            if len(self.vertices) == 0:
                value = random.choice(self.vertex)
                vert = Vertex(value)
                self.vertex.remove(value)
                self.set_vertices(vert)


            else:
                value =random.choice(self.vertex)
                vert = Vertex(value)
                self.vertex.remove(value)
                self.set_vertices(vert)


                rand_no_vertices = random.randint(1,len(self.vertices))

                for i in range(0, rand_no_vertices):
                    weight = random.randint(1,10)
                    rand_vert = random.choice(self.vertices)

                    rand_vert.set_neighbors(vert,weight)
                    vert.set_neighbors(rand_vert, weight)
    
    def breadth_first_traversal(self):
        first_vert = random.choice(self.vertices)
        print('BFS:', end='[ ')
        self.start_breadth_first_traversal(first_vert)
        print(end=']')
    
    
    def start_breadth_first_traversal(self,start):
        print(start.get_value(), end=' ')
        start.set_traverse(True)
        self.recurse_breadth_first_traversal(start)
        
    
    def recurse_breadth_first_traversal(self,ver):
        traverse = True
        
        for vertex in ver.get_neighbors():
            if not vertex.get_traverse():
                print(vertex.get_value(), end=' ')
                vertex.set_traverse(True)
                traverse = False
        
        if traverse:
            return
        
        for vertex in ver.get_neighbors():
            self.recurse_breadth_first_traversal(vertex)

# %%
                  
graph = Graph()
graph.generate_vertex()

# %%
for i in graph.get_vertices():
    print(i.get_value())
    print('Neighbors: ')
    for u in i.get_neighbors():
        print(u.get_value() , ' weight: ',i.get_neighbors()[u] )
    print()
# Out:
# 4
# Neighbors:
# 57  weight:  9
# 81  weight:  6
# 53  weight:  6
# 51  weight:  8
# 39  weight:  10
# 88  weight:  5
# 94  weight:  10
# 3  weight:  10
#
# 57
# Neighbors:
# 4  weight:  9
# 81  weight:  1
# 36  weight:  1
# 51  weight:  1
# 39  weight:  6
# 3  weight:  9
# 40  weight:  9
#
# 81
# Neighbors:
# 57  weight:  1
# 4  weight:  6
# 60  weight:  4
# 36  weight:  1
# 38  weight:  5
# 62  weight:  7
# 67  weight:  1
# 51  weight:  9
# 39  weight:  9
#
# 53
# Neighbors:
# 4  weight:  6
# 60  weight:  10
# 38  weight:  1
# 62  weight:  2
# 51  weight:  10
# 94  weight:  10
#
# 60
# Neighbors:
# 53  weight:  10
# 81  weight:  4
# 41  weight:  3
# 67  weight:  3
# 99  weight:  2
# 39  weight:  3
# 94  weight:  6
# 3  weight:  6
#
# 36
# Neighbors:
# 57  weight:  1
# 81  weight:  1
# 62  weight:  7
# 67  weight:  8
# 51  weight:  9
# 39  weight:  8
# 94  weight:  2
# 3  weight:  4
# 40  weight:  5
#
# 38
# Neighbors:
# 53  weight:  1
# 81  weight:  5
# 41  weight:  2
# 54  weight:  9
# 99  weight:  3
# 39  weight:  8
# 94  weight:  5
# 3  weight:  8
#
# 62
# Neighbors:
# 53  weight:  2
# 81  weight:  7
# 36  weight:  7
# 8  weight:  8
# 99  weight:  8
# 51  weight:  7
# 39  weight:  9
# 3  weight:  9
# 40  weight:  10
#
# 41
# Neighbors:
# 38  weight:  2
# 60  weight:  3
# 8  weight:  10
# 67  weight:  6
# 99  weight:  4
# 51  weight:  8
# 3  weight:  2
#
# 8
# Neighbors:
# 41  weight:  10
# 62  weight:  8
# 6  weight:  3
# 39  weight:  9
# 94  weight:  1
# 3  weight:  5
#
# 54
# Neighbors:
# 38  weight:  9
# 3  weight:  3
# 40  weight:  4
#
# 67
# Neighbors:
# 81  weight:  1
# 41  weight:  6
# 36  weight:  8
# 60  weight:  3
# 99  weight:  10
# 51  weight:  4
# 39  weight:  9
# 88  weight:  1
# 94  weight:  5
# 3  weight:  1
#
# 99
# Neighbors:
# 38  weight:  3
# 60  weight:  2
# 41  weight:  4
# 62  weight:  8
# 67  weight:  10
# 51  weight:  7
# 94  weight:  8
# 3  weight:  5
#
# 6
# Neighbors:
# 8  weight:  3
# 88  weight:  4
# 3  weight:  7
#
# 51
# Neighbors:
# 4  weight:  8
# 67  weight:  4
# 57  weight:  1
# 99  weight:  7
# 53  weight:  10
# 81  weight:  9
# 41  weight:  8
# 36  weight:  9
# 62  weight:  7
# 39  weight:  2
# 88  weight:  1
# 94  weight:  9
#
# 39
# Neighbors:
# 51  weight:  2
# 57  weight:  6
# 4  weight:  10
# 60  weight:  3
# 38  weight:  8
# 62  weight:  9
# 67  weight:  9
# 36  weight:  8
# 81  weight:  9
# 8  weight:  9
# 88  weight:  4
# 3  weight:  7
#
# 88
# Neighbors:
# 4  weight:  5
# 51  weight:  1
# 6  weight:  4
# 39  weight:  4
# 67  weight:  1
# 40  weight:  4
#
# 94
# Neighbors:
# 53  weight:  10
# 8  weight:  1
# 99  weight:  8
# 67  weight:  5
# 4  weight:  10
# 60  weight:  6
# 38  weight:  5
# 36  weight:  2
# 51  weight:  9
# 3  weight:  7
#
# 3
# Neighbors:
# 4  weight:  10
# 41  weight:  2
# 62  weight:  9
# 8  weight:  5
# 39  weight:  7
# 57  weight:  9
# 36  weight:  4
# 99  weight:  5
# 60  weight:  6
# 38  weight:  8
# 6  weight:  7
# 67  weight:  1
# 94  weight:  7
# 54  weight:  3
# 40  weight:  7
#
# 40
# Neighbors:
# 88  weight:  4
# 57  weight:  9
# 36  weight:  5
# 54  weight:  4
# 62  weight:  10
# 3  weight:  7
